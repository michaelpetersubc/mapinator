# %%
#using Pkg
#Pkg.add("JSON")
#Pkg.add("DotEnv")
#Pkg.add("HTTP")
#Pkg.add("JSON")
#Pkg.add("URIs")
#Pkg.add("ConfigEnv")

using HTTP, URIs,JSON

# %% [markdown]
# This is a modified version of the get_data program in the api documentation.  Designed here to illustrate error correction methods

# %%
function get_data(url)
    resp = HTTP.get(url);
    es = String(resp.body)
    return placements = JSON.parse(es)
end
# Out:
# get_data (generic function with 1 method)

# %%
placements = get_data("https://support.econjobmarket.org/api/placement_data")
println(placements[1])
# Out:
# Dict{String, Any}("to_shortname" => "Econ, U Cattolica Sacro Cuore", "to_name" => "Università Cattolica del Sacro Cuore", "to_department" => "Facoltà di Economia", "name" => "Industrial Organization", "category_id" => 7, "from_shortname" => "Economics, UCLA", "to_oid" => 1783, "recruiter_type" => 1, "description" => "Academic organization (economics department)", "from_oid" => "36", "position_name" => "Lecturer", "year" => 2003, "aid" => 4256, "to_institution_id" => 1873, "postype" => 7, "from_institution_id" => "6", "from_institution_name" => "University of California Los Angeles (UCLA)")

# %% [markdown]
# To flag the entries I use an elementary method.  First I'll create an empty set to store the placements I have already checked called `records` and another set to hold the aids I want to flag called `flags`.
#
# Then I'll iterate through the placements one by one and check whether each placement is already in `records`.  If it is there already I'll try to add the aid to `flags`.  If it isn't there I'll add the record to `records`

# %%
records = Set()
flags = Set()
#x = [1,2,3]
#push!(s,[1,2,3])
#println(s)
# Out:
# Set{Any}()

# %%
for placement in placements
    t = [placement["aid"],placement["to_oid"],placement["from_oid"]]
    #println( "checking ", t)
    if t in records
        push!(flags,placement["aid"])
    else
        push!(records,t)
    end 
end

# %%
println(length(records))
println(length(flags))
# Out:
# 16354
# 312

# %%
println(flags)
# Out:
# Set(Any[40533, 31882, 42840, 26076, 32051, 45359, 60015, 50965, 59967, 25891, 25056, 33228, 56152, 25894, 31968, 56305, 41781, 25036, 46113, 50112, 53829, 4609, 31232, 53633, 27841, 48744, 30983, 48773, 26720, 60375, 8496, 5537, 25234, 50934, 3794, 1223, 19489, 52309, 54970, 4699, 26030, 44179, 40786, 24230, 58633, 42741, 28819, 35658, 30477, 47606, 53083, 44035, 48375, 38769, 47007, 43929, 42096, 43924, 38677, 2955, 56812, 55473, 55177, 56188, 32852, 41667, 47592, 9346, 29450, 35946, 40799, 60076, 28321, 43239, 7279, 48926, 40363, 43665, 44111, 35945, 41245, 46870, 29184, 49851, 44250, 55537, 32231, 40411, 43979, 27636, 23714, 45888, 49955, 43159, 54729, 32944, 36767, 28223, 60130, 32657, 47462, 23856, 15586, 25057, 57323, 29607, 41856, 43561, 46163, 33171, 30780, 43585, 26915, 54259, 49610, 55257, 6418, 49122, 30343, 44811, 7334, 52720, 46596, 59420, 41859, 25462, 50938, 52077, 31431, 55876, 1482, 29090, 41426, 29323, 50811, 28393, 56055, 27592, 54483, 24658, 52102, 26060, 29283, 48290, 41988, 46874, 25408, 29930, 43913, 42559, 52201, 23474, 26439, 43878, 43057, 14748, 28024, 43228, 57137, 52144, 47602, 28584, 20556, 24119, 35984, 50069, 55775, 45588, 51523, 48311, 42961, 46866, 44122, 52079, 44050, 28267, 44683, 2332, 48726, 40381, 44900, 56384, 1134, 1883, 1079, 59902, 36038, 44165, 47950, 4353, 14071, 51661, 26931, 28391, 39965, 51633, 52869, 445, 46997, 53933, 54145, 47147, 45613, 45665, 47672, 46718, 27142, 3797, 44293, 42097, 31805, 2163, 27789, 35940, 42312, 52414, 34090, 44806, 43502, 1486, 42680, 50694, 41393, 29719, 52842, 47172, 9897, 27725, 36728, 27210, 50079, 40572, 25525, 2080, 7704, 60057, 26650, 15331, 41148, 51822, 50621, 42985, 56353, 39410, 21416, 34430, 47130, 41882, 29511, 31248, 33879, 53029, 24704, 19483, 28867, 27975, 44824, 41609, 48917, 45140, 51771, 27101, 11614, 46905, 28097, 30023, 28214, 22240, 51345, 41178, 42165, 36856, 46199, 51482, 9423, 43892, 1487, 46635, 51726, 3676, 55885, 43005, 39330, 23794, 25273, 37960, 28685, 47684, 30052, 44052, 53336, 51460, 16713, 47695, 26606, 52152, 2135, 46991, 10690, 26131, 40504, 38422, 36091, 31468, 26911, 24912, 48463, 55374, 44498, 51938, 47493, 43870])
