# %%
using JSON
using Random
using Distributions
using MySQL
using DotEnv
include("/home/peters/code/mapinator/estimation/bootstrap_functions.jl")
include("/home/peters/code/mapinator/estimation/functions.jl")
YEAR_INTERVAL = 2003:2023  # change this to select the years of data to include in the estimation
NUM = 5 # variable set it here
NUMSINKS = 6 #4 sinks are assumed in some of the code
sinks = ["Other Academic","Government","Private Sector","Teaching Universities","Postdoc", "Sessionals","Column Totals"]
sample = 10000;
iterate = 40
function name_to_oid(name, institution_mapping)
    for (key, value) in institution_mapping
        if value == name
            return key
        end
    end
    return "not found"
end
function run_sampler(placements,sample, cfg)
    d = DBInterface.connect(MySQL.Connection,cfg["host"], cfg["user"], cfg["password"], db =cfg["database"], port = parse(Int64,cfg["port"]));
    query = "insert into bootstrap_trials set trial_time=now(),sample_size=?,number_of_tiers=?"
    create_trial_statement =  DBInterface.prepare(d, query);
    query = "insert into bootstrap_data set trial_id=?,institution_id=?,estimated_tier=?"
    add_data_statement = DBInterface.prepare(d, query);
    academic_builder, sink_builder, academic, acd_sink, gov_sink, pri_sink, tch_sink, postdoc, lecturer, institution_mapping = bootstrap_functions.sampler(placements, sample)
    institutions, out = functions.create_adjacency_matrix(academic_builder, sink_builder, academic,acd_sink, gov_sink, pri_sink, tch_sink, postdoc, lecturer);
    est_obj, est_alloc = functions.doit(out, collect(academic),collect(acd_sink), collect(gov_sink), collect(pri_sink), collect(tch_sink), collect(postdoc), collect(lecturer),institutions, NUM, NUMSINKS);
    est_mat, est_count = functions.bucket_extract(est_alloc, out, NUM, NUMSINKS)
    t_table, t_allocation = functions.tiered_allocation(est_mat, est_count, institutions, est_alloc, NUM, NUMSINKS);
    c = DBInterface.execute(create_trial_statement, [sample, NUM])
    trial_id = DBInterface.lastrowid(c)
    for j in 1:NUM
        #println("Tier $j:")
        for (i, type) in enumerate(t_allocation)
            if type == j
                #println("  ", institutions[i], " (institution_id ", name_to_oid(institutions[i], institution_mapping), ")")
                cc = DBInterface.execute(add_data_statement, [trial_id, name_to_oid(institutions[i], institution_mapping), j])
            end
        end
    end
    DBInterface.close!(d)
    return institutions, t_allocation, institution_mapping, trial_id
end
# Out:
# run_sampler (generic function with 1 method)

# %%
#println(t_allocation)
#institutions, out = functions.create_adjacency_matrix(academic_builder, sink_builder, academic,acd_sink, gov_sink, pri_sink, tch_sink, postdoc, lecturer);

# %%
placements = bootstrap_functions.process_data(YEAR_INTERVAL);
cfg = DotEnv.config()

Threads.@threads for k in 1:iterate
    println("run = $k on thread $(Threads.threadid())")
    institutions, t_allocation, institution_mapping, trial_id = run_sampler(placements, sample, cfg)
    println("Finished trial_id ",trial_id)
end
# Out:
# run = 25 on thread 7
# run = 33 on thread 9
# run = 21 on thread 6
# run = 1 on thread 1
# run = 37 on thread 10
# run = 9 on thread 3
# run = 13 on thread 4
# run = 5 on thread 2
# run = 29 on thread 8
# run = 17 on thread 5
# FAULT: hiring 5 with graduating 2: downward rate: 10, upward rate: 16
# FAULT: hiring 5 with graduating 1: downward rate: 1, upward rate: 3
# FAULT: hiring 5 with graduating 3: downward rate: 35, upward rate: 37
# FAULT: hiring 5 with graduating 4: downward rate: 2, upward rate: 6
# FAULT: hiring 5 with graduating 3: downward rate: 17, upward rate: 29
# Finished trial_id 263
# run = 30 on thread 8
# Finished trial_id 262
# run = 38 on thread 10
# FAULT: hiring 5 with graduating 3: downward rate: 13, upward rate: 15
# Finished trial_id 264
# run = 22 on thread 6
# FAULT: hiring 5 with graduating 2: downward rate: 4, upward rate: 14
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 0
# FAULT: hiring 5 with graduating 3: downward rate: 16, upward rate: 19
# Finished trial_id 266
# run = 2 on thread 1
# Finished trial_id 265
# run = 34 on thread 9
# Finished trial_id 267
# run = 18 on thread 5
# FAULT: hiring 5 with graduating 1: downward rate: 4, upward rate: 4
# FAULT: hiring 5 with graduating 3: downward rate: 24, upward rate: 26
# Finished trial_id 268
# run = 14 on thread 4
# FAULT: hiring 5 with graduating 4: downward rate: 0, upward rate: 2
# Finished trial_id 269
# run = 10 on thread 3
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 0
# FAULT: hiring 5 with graduating 2: downward rate: 4, upward rate: 5
# FAULT: hiring 5 with graduating 3: downward rate: 13, upward rate: 22
# Finished trial_id 270
# run = 31 on thread 8
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 0
# FAULT: hiring 5 with graduating 2: downward rate: 0, upward rate: 10
# FAULT: hiring 5 with graduating 3: downward rate: 0, upward rate: 18
# FAULT: hiring 5 with graduating 4: downward rate: 4, upward rate: 13
# Finished trial_id 271
# run = 6 on thread 2
# Finished trial_id 272
# run = 26 on thread 7
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 2
# FAULT: hiring 5 with graduating 2: downward rate: 11, upward rate: 21
# Finished trial_id 273
# run = 23 on thread 6
# FAULT: hiring 5 with graduating 2: downward rate: 6, upward rate: 9
# Finished trial_id 274
# run = 19 on thread 5
# FAULT: hiring 5 with graduating 2: downward rate: 8, upward rate: 11
# FAULT: hiring 2 with graduating 1: downward rate: 52, upward rate: 295
# FAULT: hiring 4 with graduating 1: downward rate: 32, upward rate: 284
# FAULT: hiring 4 with graduating 2: downward rate: 47, upward rate: 238
# FAULT: hiring 4 with graduating 3: downward rate: 4, upward rate: 229
# FAULT: hiring 5 with graduating 3: downward rate: 6, upward rate: 10
# Finished trial_id 275
# run = 3 on thread 1
# FAULT: hiring 5 with graduating 1: downward rate: 3, upward rate: 5
# FAULT: hiring 5 with graduating 3: downward rate: 24, upward rate: 36
# Finished trial_id 276
# run = 15 on thread 4
# Finished trial_id 277
# run = 7 on thread 2
# Finished trial_id 278
# run = 11 on thread 3
# Finished trial_id 279
# run = 39 on thread 10
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 0
# FAULT: hiring 5 with graduating 2: downward rate: 10, upward rate: 19
# FAULT: hiring 5 with graduating 3: downward rate: 2, upward rate: 4
# Finished trial_id 280
# run = 27 on thread 7
# FAULT: hiring 5 with graduating 2: downward rate: 9, upward rate: 12
# FAULT: hiring 5 with graduating 4: downward rate: 11, upward rate: 12
# Finished trial_id 281
# run = 35 on thread 9
# Finished trial_id 282
# run = 12 on thread 3
# FAULT: hiring 5 with graduating 2: downward rate: 5, upward rate: 6
# FAULT: hiring 5 with graduating 4: downward rate: 0, upward rate: 2
# FAULT: hiring 5 with graduating 2: downward rate: 3, upward rate: 7
# FAULT: hiring 5 with graduating 3: downward rate: 5, upward rate: 16
# Finished trial_id 283
# run = 8 on thread 2
# Finished trial_id 284
# run = 16 on thread 4
# FAULT: hiring 5 with graduating 2: downward rate: 10, upward rate: 12
# Finished trial_id 285
# run = 20 on thread 5
# Finished trial_id 286
# run = 28 on thread 7
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 2
# Finished trial_id 287
# run = 40 on thread 10
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 0
# FAULT: hiring 5 with graduating 4: downward rate: 5, upward rate: 8
# FAULT: hiring 4 with graduating 2: downward rate: 24, upward rate: 27
# FAULT: hiring 5 with graduating 3: downward rate: 5, upward rate: 16
# FAULT: hiring 5 with graduating 4: downward rate: 0, upward rate: 0
# Finished trial_id 288
# run = 32 on thread 8
# Finished trial_id 289
# run = 4 on thread 1
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 1
# FAULT: hiring 5 with graduating 2: downward rate: 3, upward rate: 8
# Finished trial_id 290
# run = 36 on thread 9
# Finished trial_id 291
# FAULT: hiring 4 with graduating 2: downward rate: 14, upward rate: 15
# FAULT: hiring 5 with graduating 4: downward rate: 0, upward rate: 0
# Finished trial_id 292
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 1
# FAULT: hiring 5 with graduating 2: downward rate: 9, upward rate: 10
# FAULT: hiring 5 with graduating 3: downward rate: 14, upward rate: 35
# Finished trial_id 293
# FAULT: hiring 5 with graduating 3: downward rate: 13, upward rate: 20
# FAULT: hiring 5 with graduating 4: downward rate: 12, upward rate: 14
# Finished trial_id 294
# run = 24 on thread 6
# FAULT: hiring 5 with graduating 4: downward rate: 0, upward rate: 0
# Finished trial_id 295
# Finished trial_id 296
# FAULT: hiring 5 with graduating 1: downward rate: 7, upward rate: 7
# FAULT: hiring 5 with graduating 2: downward rate: 10, upward rate: 13
# FAULT: hiring 5 with graduating 3: downward rate: 15, upward rate: 19
# FAULT: hiring 5 with graduating 4: downward rate: 3, upward rate: 6
# Finished trial_id 297
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 5
# FAULT: hiring 5 with graduating 2: downward rate: 0, upward rate: 2
# FAULT: hiring 5 with graduating 4: downward rate: 0, upward rate: 0
# Finished trial_id 298
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 0
# FAULT: hiring 5 with graduating 2: downward rate: 10, upward rate: 10
# FAULT: hiring 5 with graduating 3: downward rate: 11, upward rate: 32
# FAULT: hiring 5 with graduating 4: downward rate: 0, upward rate: 5
# Finished trial_id 299
# FAULT: hiring 4 with graduating 3: downward rate: 21, upward rate: 24
# Finished trial_id 300
# FAULT: hiring 5 with graduating 1: downward rate: 0, upward rate: 1
# FAULT: hiring 5 with graduating 2: downward rate: 0, upward rate: 4
# FAULT: hiring 5 with graduating 3: downward rate: 23, upward rate: 26
# Finished trial_id 301
