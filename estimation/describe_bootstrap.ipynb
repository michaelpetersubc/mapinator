# %% [markdown]
# # Bootstrap Analaysis Code for SBM
#
# James Yu, 10 June 2023

# %%
using FileIO, Statistics
NUMBER_OF_TYPES = 4
NUMBER_OF_SINKS = 4;

# %% [markdown]
# The bootstrap output is stored as a serialized `jld2` file. This allows complicated Julia data structures to be packed neatly into storable file objects.

# %%
bootstrap_output = load(".estimates/bootstrap_output.jld2")
# Out:
# Dict{String, Any} with 4 entries:
#   "placement_rates"  => [1.25207 0.0786713 0.0109428 0.000239234; 0.487762 0.07…
#   "type_allocation"  => [1.0 1.0 … 1.0 1.0; 4.0 4.0 … 4.0 4.0; … ; 8.0 8.0 … 8.…
#   "placement_counts" => [606.0 90.0 39.0 1.0; 558.0 208.0 65.0 13.0; … ; 506.0 …
#   "dept_labels"      => ["Columbia University" "Columbia University" … "Columbi…

# %% [markdown]
# We store four components in this file: the Poisson placement rates, the total placements between departments, as well as the type allocation and associated names of these departments.

# %% [markdown]
# Given the raw data, we can compute some summary statistics:

# %%
mean(bootstrap_output["placement_rates"], dims = 3)
# Out:
# 8×4×1 Array{Float64, 3}:
# [:, :, 1] =
#  1.34603    0.110287   0.0118673   0.00135527
#  0.576721   0.111215   0.0111147   0.00139103
#  0.246182   0.0947503  0.0125098   0.00115544
#  0.0170196  0.0138622  0.00249879  0.00118616
#  0.349849   0.071794   0.0135029   0.0052838
#  0.18117    0.0551953  0.00745912  0.00179296
#  0.209035   0.0399636  0.00457567  0.000676247
#  0.0265566  0.0150036  0.00345671  0.000840428

# %%
var(bootstrap_output["placement_rates"], dims = 3)
# Out:
# 8×4×1 Array{Float64, 3}:
# [:, :, 1] =
#  0.0357659    0.00207511   3.5916e-6   1.51625e-6
#  0.0110953    0.00107924   8.67546e-6  3.69581e-7
#  0.00154718   0.000424547  8.39806e-6  5.6894e-8
#  4.6309e-5    1.96978e-5   3.3682e-7   2.97026e-8
#  0.00136872   0.000272191  4.17841e-6  9.44873e-7
#  0.000124051  0.000142728  1.32766e-6  1.36861e-7
#  0.000325863  7.31036e-5   8.40776e-7  5.6247e-8
#  6.1505e-7    4.35281e-6   2.57746e-7  7.52552e-9

# %% [markdown]
# For the total placements, we can do a similar thing:

# %%
mean(bootstrap_output["placement_counts"], dims = 3)
# Out:
# 8×4×1 Array{Float64, 3}:
# [:, :, 1] =
#  551.5   89.4   37.0    5.7
#  485.9  190.6   70.2   12.3
#  761.3  603.2  294.5   37.2
#   73.1  118.7   80.6   52.1
#  148.3   62.2   43.6   23.0
#  378.5  234.6  118.0   38.5
#  485.5  189.9   80.8   16.3
#  452.4  523.1  444.3  146.7

# %%
std(bootstrap_output["placement_counts"], dims = 3)
# Out:
# 8×4×1 Array{Float64, 3}:
# [:, :, 1] =
#  75.7397  17.0046    5.03322   4.80856
#  57.9836  27.1752    6.25033   5.90762
#  35.4371  49.012    43.1618    8.24352
#  35.0411  31.1129   20.7429   14.2474
#  11.5089   7.45058   4.59952   3.8873
#  35.8554  20.8444   12.9013    8.61846
#  26.0352  19.0114   13.5384    6.16532
#  56.6219  32.6716   48.9059   22.101

# %% [markdown]
# We are also interested in the frequency of assignment of each department to a given type. To analyze this, we want to create a table measuring the frequency by which each department is placed in each type. Thus:

# %%
average_type_allocation = mean(bootstrap_output["type_allocation"], dims = 2)

for sorted_type in 1:NUMBER_OF_TYPES
    counter = 0
    inst_hold = []
    println("TYPE $sorted_type:")
    for (i, assign_type) in enumerate(Int.(round.(average_type_allocation)))
        if sorted_type == assign_type
            push!(inst_hold, (i, bootstrap_output["dept_labels"][i, 1]))
            counter += 1
        end
    end
    for (i, dept) in sort(inst_hold, by = x->x[2])
        frequency = bootstrap_output["type_allocation"][i, :]
        counter_table = zeros(Int64, NUMBER_OF_TYPES)
        for element in frequency
            counter_table[Int(element)] += 1
        end
        print(dept)
        print(": Avg Type $(average_type_allocation[i]) (")
        seen = false
        for (t, num) in enumerate(counter_table)
            if num != 0
                if seen print(", ") end
                seen = true
                print("Type $t: $(num)x")
            end
        end
        println(")")
    end
    println("Total Institutions: $counter")
    println()
end
# Out:
# TYPE 1:
# Boston University: Avg Type 1.0 (Type 1: 10x)
# Columbia University: Avg Type 1.0 (Type 1: 10x)
# Duke University: Avg Type 1.0 (Type 1: 10x)
# Harvard University: Avg Type 1.0 (Type 1: 10x)
# London School of Economics and Political Science: Avg Type 1.1 (Type 1: 9x, Type 2: 1x)
# Massachusetts Institute of Technology: Avg Type 1.2 (Type 1: 8x, Type 2: 2x)
# New York University: Avg Type 1.0 (Type 1: 10x)
# Northwestern University: Avg Type 1.0 (Type 1: 10x)
# Ohio State University: Avg Type 1.4 (Type 1: 6x, Type 2: 4x)
# Princeton University: Avg Type 1.0 (Type 1: 10x)
# Stanford University: Avg Type 1.0 (Type 1: 10x)
# University of California Los Angeles (UCLA): Avg Type 1.0 (Type 1: 10x)
# University of California, Berkeley: Avg Type 1.0 (Type 1: 10x)
# University of Chicago: Avg Type 1.0 (Type 1: 10x)
# University of Maryland: Avg Type 1.0 (Type 1: 10x)
# University of Michigan: Avg Type 1.0 (Type 1: 10x)
# University of Pennsylvania: Avg Type 1.0 (Type 1: 10x)
# University of Wisconsin, Madison: Avg Type 1.0 (Type 1: 10x)
# Yale University: Avg Type 1.0 (Type 1: 10x)
# Total Institutions: 19
#
# TYPE 2:
# Arizona State University: Avg Type 2.0 (Type 2: 10x)
# Bocconi University: Avg Type 2.0 (Type 2: 10x)
# Boston College: Avg Type 2.0 (Type 2: 10x)
# Brown University: Avg Type 1.5 (Type 1: 5x, Type 2: 5x)
# Carnegie Mellon University: Avg Type 2.0 (Type 2: 10x)
# Cornell University: Avg Type 1.5 (Type 1: 5x, Type 2: 5x)
# Johns Hopkins University: Avg Type 2.0 (Type 2: 10x)
# Michigan State University: Avg Type 2.0 (Type 2: 10x)
# National University of Singapore: Avg Type 2.1 (Type 2: 9x, Type 3: 1x)
# Pennsylvania State University: Avg Type 1.6 (Type 1: 4x, Type 2: 6x)
# Purdue University: Avg Type 2.0 (Type 2: 10x)
# Stockholm School of Economics: Avg Type 2.1 (Type 2: 9x, Type 3: 1x)
# Stockholm University: Avg Type 2.4 (Type 2: 6x, Type 3: 4x)
# Texas A&M University, College Station: Avg Type 2.0 (Type 2: 10x)
# Tilburg University: Avg Type 2.0 (Type 2: 10x)
# Universitat Pompeu Fabra: Avg Type 2.0 (Type 2: 10x)
# University College London: Avg Type 2.0 (Type 2: 10x)
# University of Arizona: Avg Type 2.5 (Type 2: 5x, Type 3: 5x)
# University of Bonn: Avg Type 2.0 (Type 2: 10x)
# University of British Columbia: Avg Type 2.0 (Type 2: 10x)
# University of California, Davis: Avg Type 2.0 (Type 2: 10x)
# University of California, Irvine: Avg Type 2.4 (Type 2: 6x, Type 3: 4x)
# University of Illinois at Urbana-Champaign: Avg Type 2.4 (Type 2: 6x, Type 3: 4x)
# University of Mannheim: Avg Type 2.0 (Type 2: 10x)
# University of Minnesota, Twin Cities: Avg Type 2.0 (Type 2: 10x)
# University of Notre Dame: Avg Type 2.0 (Type 2: 10x)
# University of Nottingham: Avg Type 2.4 (Type 2: 6x, Type 3: 4x)
# University of Oxford: Avg Type 2.0 (Type 2: 10x)
# University of Rochester: Avg Type 2.0 (Type 2: 10x)
# University of Southern California: Avg Type 2.0 (Type 2: 10x)
# University of Texas at Austin: Avg Type 2.0 (Type 2: 10x)
# University of Toronto: Avg Type 1.5 (Type 1: 5x, Type 2: 5x)
# University of Virginia: Avg Type 1.8 (Type 1: 2x, Type 2: 8x)
# University of Warwick: Avg Type 2.0 (Type 2: 10x)
# University of Washington: Avg Type 2.0 (Type 2: 10x)
# Université Toulouse Capitole: Avg Type 2.0 (Type 2: 10x)
# Vanderbilt University: Avg Type 2.0 (Type 2: 10x)
# Vrije Universiteit Amsterdam: Avg Type 2.4 (Type 2: 6x, Type 3: 4x)
# Washington State University: Avg Type 2.0 (Type 2: 10x)
# Washington University in St. Louis: Avg Type 2.0 (Type 2: 10x)
# Total Institutions: 40
#
# TYPE 3:
# Aalto University: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# Aarhus University: Avg Type 3.0 (Type 3: 10x)
# American University: Avg Type 3.0 (Type 3: 10x)
# Auburn University: Avg Type 3.0 (Type 3: 10x)
# Australian National University: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# BI Norwegian Business School: Avg Type 3.0 (Type 3: 10x)
# Binghamton University (SUNY): Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# CEMFI: Avg Type 2.9 (Type 2: 1x, Type 3: 9x)
# California Institute of Technology (Caltech): Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# Carleton University: Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# Central European University: Avg Type 3.4 (Type 3: 6x, Type 4: 4x)
# Chinese University of Hong Kong: Avg Type 3.0 (Type 3: 10x)
# Clemson University: Avg Type 2.8 (Type 2: 2x, Type 3: 8x)
# Colorado State University: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# Concordia University: Avg Type 3.0 (Type 3: 10x)
# Copenhagen Business School: Avg Type 3.0 (Type 3: 10x)
# Drexel University: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# ETH Zurich: Avg Type 3.0 (Type 3: 10x)
# Ecole Polytechnique (IP Paris): Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# Emory University: Avg Type 3.0 (Type 3: 10x)
# Erasmus University Rotterdam: Avg Type 2.8 (Type 2: 2x, Type 3: 8x)
# European University Institute: Avg Type 2.7 (Type 2: 3x, Type 3: 7x)
# Florida International University: Avg Type 3.3 (Type 3: 7x, Type 4: 3x)
# Florida State University: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# Fudan University: Avg Type 3.0 (Type 3: 10x)
# Fundação Getulio Vargas (FGV): Avg Type 3.3 (Type 3: 7x, Type 4: 3x)
# George Mason University: Avg Type 3.0 (Type 3: 10x)
# George Washington University: Avg Type 2.7 (Type 2: 3x, Type 3: 7x)
# Georgetown University: Avg Type 2.7 (Type 2: 3x, Type 3: 7x)
# Georgia Institute of Technology: Avg Type 3.0 (Type 3: 10x)
# Georgia State University: Avg Type 3.0 (Type 3: 10x)
# Goethe-Universität Frankfurt am Main: Avg Type 3.0 (Type 3: 10x)
# HEC Paris: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# Hebrew University of Jerusalem: Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# Hong Kong Baptist University: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# Hong Kong Polytechnic University: Avg Type 3.4 (Type 3: 6x, Type 4: 4x)
# Hong Kong University of Science and Technology: Avg Type 2.8 (Type 2: 2x, Type 3: 8x)
# Humboldt University Berlin: Avg Type 3.4 (Type 3: 6x, Type 4: 4x)
# INSEAD: Avg Type 3.0 (Type 3: 10x)
# Imperial College London: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# Indian Institute of Technology, Kanpur: Avg Type 3.4 (Type 3: 6x, Type 4: 4x)
# Indiana University Bloomington: Avg Type 3.0 (Type 3: 10x)
# Instituto Tecnologico Autónomo de Mexico (ITAM): Avg Type 3.0 (Type 3: 10x)
# Iowa State University: Avg Type 3.0 (Type 3: 10x)
# Kansas State University: Avg Type 2.9 (Type 2: 1x, Type 3: 9x)
# Katholieke Universiteit Leuven: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# London Business School: Avg Type 2.8 (Type 2: 2x, Type 3: 8x)
# Louisiana State University: Avg Type 3.0 (Type 3: 10x)
# Ludwig-Maximilians-Universitat München (LMU) (University of Munich): Avg Type 3.0 (Type 3: 10x)
# Lund University: Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# Maastricht University: Avg Type 2.7 (Type 2: 3x, Type 3: 7x)
# McGill University: Avg Type 2.9 (Type 2: 1x, Type 3: 9x)
# McMaster University: Avg Type 3.0 (Type 3: 10x)
# Miami University: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# Middle Tennessee State University: Avg Type 3.0 (Type 3: 10x)
# Monash University: Avg Type 3.0 (Type 3: 10x)
# Nanyang Technological University: Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# New Economic School: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# New York University Abu Dhabi: Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# New York University Shanghai: Avg Type 3.3 (Type 3: 7x, Type 4: 3x)
# North Carolina State University: Avg Type 3.0 (Type 3: 10x)
# Northeastern University: Avg Type 3.0 (Type 3: 10x)
# Oklahoma State University: Avg Type 3.4 (Type 3: 6x, Type 4: 4x)
# Oregon State University: Avg Type 3.0 (Type 3: 10x)
# Peking University: Avg Type 3.0 (Type 3: 10x)
# Pontificia Universidad Católica de Chile: Avg Type 3.0 (Type 3: 10x)
# Queen Mary University of London: Avg Type 3.0 (Type 3: 10x)
# Queen's University: Avg Type 3.0 (Type 3: 10x)
# Rice University: Avg Type 2.6 (Type 2: 4x, Type 3: 6x)
# Rutgers, The State University of New Jersey: Avg Type 3.0 (Type 3: 10x)
# Sciences Po: Avg Type 3.0 (Type 3: 10x)
# Shanghai University of Finance and Economics: Avg Type 3.0 (Type 3: 10x)
# Simon Fraser University: Avg Type 2.6 (Type 2: 4x, Type 3: 6x)
# Singapore Management University: Avg Type 2.9 (Type 2: 1x, Type 3: 9x)
# Southern Methodist University: Avg Type 3.0 (Type 3: 10x)
# Stony Brook University (SUNY): Avg Type 3.0 (Type 3: 10x)
# Syracuse University: Avg Type 2.6 (Type 2: 4x, Type 3: 6x)
# Tel Aviv University: Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# Temple University: Avg Type 3.0 (Type 3: 10x)
# Texas Tech University: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# The New School: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# Toronto Metropolitan University: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# Tsinghua University: Avg Type 3.0 (Type 3: 10x)
# Tufts University: Avg Type 3.0 (Type 3: 10x)
# Tulane University: Avg Type 3.0 (Type 3: 10x)
# Universidad Carlos III de Madrid: Avg Type 2.6 (Type 2: 4x, Type 3: 6x)
# Universidad de Navarra: Avg Type 3.0 (Type 3: 10x)
# Universidad de los Andes: Avg Type 3.0 (Type 3: 10x)
# Universitat Autònoma de Barcelona: Avg Type 2.7 (Type 2: 3x, Type 3: 7x)
# University of Alabama: Avg Type 3.0 (Type 3: 10x)
# University of Alberta: Avg Type 3.3 (Type 3: 7x, Type 4: 3x)
# University of Amsterdam: Avg Type 3.0 (Type 3: 10x)
# University of Arkansas: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# University of Bristol: Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# University of Calgary: Avg Type 3.0 (Type 3: 10x)
# University of California, Riverside: Avg Type 2.7 (Type 2: 3x, Type 3: 7x)
# University of California, San Diego: Avg Type 2.7 (Type 2: 3x, Type 3: 7x)
# University of California, Santa Barbara: Avg Type 2.9 (Type 2: 1x, Type 3: 9x)
# University of California, Santa Cruz: Avg Type 3.0 (Type 3: 10x)
# University of Cambridge: Avg Type 2.6 (Type 2: 4x, Type 3: 6x)
# University of Colorado, Boulder: Avg Type 2.8 (Type 2: 2x, Type 3: 8x)
# University of Connecticut: Avg Type 3.0 (Type 3: 10x)
# University of Copenhagen: Avg Type 3.0 (Type 3: 10x)
# University of Delaware: Avg Type 3.0 (Type 3: 10x)
# University of Edinburgh: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# University of Essex: Avg Type 3.0 (Type 3: 10x)
# University of Exeter: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# University of Florida: Avg Type 3.0 (Type 3: 10x)
# University of Georgia: Avg Type 3.0 (Type 3: 10x)
# University of Glasgow: Avg Type 3.0 (Type 3: 10x)
# University of Gothenburg: Avg Type 3.0 (Type 3: 10x)
# University of Groningen: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# University of Hawaiʻi at Mānoa: Avg Type 3.0 (Type 3: 10x)
# University of Hong Kong: Avg Type 3.0 (Type 3: 10x)
# University of Houston: Avg Type 2.9 (Type 2: 1x, Type 3: 9x)
# University of Illinois at Chicago: Avg Type 3.0 (Type 3: 10x)
# University of Iowa: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# University of Kansas: Avg Type 2.7 (Type 2: 3x, Type 3: 7x)
# University of Kent: Avg Type 3.4 (Type 3: 6x, Type 4: 4x)
# University of Kentucky: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# University of Lausanne: Avg Type 3.0 (Type 3: 10x)
# University of Leicester: Avg Type 3.3 (Type 3: 7x, Type 4: 3x)
# University of Massachusetts, Amherst: Avg Type 3.0 (Type 3: 10x)
# University of Melbourne: Avg Type 3.0 (Type 3: 10x)
# University of Miami: Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# University of Missouri, Columbia: Avg Type 2.9 (Type 2: 1x, Type 3: 9x)
# University of New South Wales (UNSW), Sydney: Avg Type 3.0 (Type 3: 10x)
# University of North Carolina, Chapel Hill: Avg Type 2.7 (Type 2: 3x, Type 3: 7x)
# University of Oklahoma: Avg Type 3.0 (Type 3: 10x)
# University of Oregon: Avg Type 3.0 (Type 3: 10x)
# University of Oslo: Avg Type 3.4 (Type 3: 6x, Type 4: 4x)
# University of Pittsburgh: Avg Type 2.9 (Type 2: 1x, Type 3: 9x)
# University of Queensland: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# University of South Carolina: Avg Type 3.4 (Type 3: 6x, Type 4: 4x)
# University of St Andrews: Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# University of Surrey: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# University of Sydney: Avg Type 3.0 (Type 3: 10x)
# University of Texas at Dallas: Avg Type 3.4 (Type 3: 6x, Type 4: 4x)
# University of Tokyo: Avg Type 3.0 (Type 3: 10x)
# University of Utah: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# University of Vienna: Avg Type 3.0 (Type 3: 10x)
# University of Zurich: Avg Type 3.0 (Type 3: 10x)
# Università di Bologna: Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# Université Libre de Bruxelles: Avg Type 3.4 (Type 3: 6x, Type 4: 4x)
# Université du Québec à Montréal (UQAM): Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# Universíté de Montréal: Avg Type 3.1 (Type 3: 9x, Type 4: 1x)
# Uppsala University: Avg Type 3.0 (Type 3: 10x)
# Utrecht University: Avg Type 3.2 (Type 3: 8x, Type 4: 2x)
# Virginia Tech: Avg Type 2.9 (Type 2: 1x, Type 3: 9x)
# West Virginia University: Avg Type 3.0 (Type 3: 10x)
# Western University: Avg Type 3.0 (Type 3: 10x)
# Wuhan University: Avg Type 3.0 (Type 3: 10x)
# École d'Économie de Paris: Avg Type 3.0 (Type 3: 10x)
# Total Institutions: 153
#
# TYPE 4:
# Aix-Marseille Université: Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# Aligarh Muslim University: Avg Type 4.0 (Type 4: 10x)
# Aristotle University of Thessaloniki: Avg Type 4.0 (Type 4: 10x)
# Ball State University: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Bank of Finland: Avg Type 4.0 (Type 4: 10x)
# Barcelona Graduate School of Economics: Avg Type 4.0 (Type 4: 10x)
# Bentley University: Avg Type 4.0 (Type 4: 10x)
# Bharathidasan University: Avg Type 4.0 (Type 4: 10x)
# Bilkent University: Avg Type 3.7 (Type 3: 3x, Type 4: 7x)
# Birkbeck College, University of London: Avg Type 4.0 (Type 4: 10x)
# Bournemouth University: Avg Type 4.0 (Type 4: 10x)
# Brandeis University: Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# CERGE-EI (Center for Economic Research and Graduate Education – Economics Institute): Avg Type 3.7 (Type 3: 3x, Type 4: 7x)
# Ca' Foscari University Venice: Avg Type 4.0 (Type 4: 10x)
# California State Polytechnic University, Pomona: Avg Type 4.0 (Type 4: 10x)
# Center for Research in Economics and Statistics (CREST): Avg Type 4.0 (Type 4: 10x)
# Chr. Michelsen Institute (CMI): Avg Type 4.0 (Type 4: 10x)
# City University of London: Avg Type 3.5 (Type 3: 5x, Type 4: 5x)
# City University of New York Graduate Center: Avg Type 3.7 (Type 3: 3x, Type 4: 7x)
# Claremont Graduate University: Avg Type 4.0 (Type 4: 10x)
# Clark University: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# Cochin University of Science and Technology: Avg Type 4.0 (Type 4: 10x)
# Colorado School of Mines: Avg Type 4.0 (Type 4: 10x)
# Covenant University: Avg Type 4.0 (Type 4: 10x)
# Dalhousie University: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# Dalian University of Technology: Avg Type 4.0 (Type 4: 10x)
# Deakin University: Avg Type 4.0 (Type 4: 10x)
# Delft University of Technology: Avg Type 4.0 (Type 4: 10x)
# Dublin City University: Avg Type 4.0 (Type 4: 10x)
# Durham University: Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# EDHEC Business School: Avg Type 4.0 (Type 4: 10x)
# ESCP Business School: Avg Type 4.0 (Type 4: 10x)
# ESMT Berlin: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# ESSEC Business School: Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# Eastern Kentucky University: Avg Type 3.5 (Type 3: 5x, Type 4: 5x)
# Federal Reserve Bank of New York: Avg Type 4.0 (Type 4: 10x)
# Federal University of Paraná: Avg Type 4.0 (Type 4: 10x)
# Fordham University: Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# Frankfurt School of Finance & Management: Avg Type 4.0 (Type 4: 10x)
# Freie Universität Berlin: Avg Type 4.0 (Type 4: 10x)
# Ghent University: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Graduate Institute of International and Development Studies: Avg Type 4.0 (Type 4: 10x)
# Hanken School of Economics: Avg Type 4.0 (Type 4: 10x)
# Heidelberg University: Avg Type 4.0 (Type 4: 10x)
# Heriot Watt University: Avg Type 4.0 (Type 4: 10x)
# Howard University: Avg Type 4.0 (Type 4: 10x)
# IE University: Avg Type 4.0 (Type 4: 10x)
# IMT School for Advanced Studies Lucca: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# ISM University of Management and Economics: Avg Type 4.0 (Type 4: 10x)
# Indian Institute of Management Bangalore: Avg Type 4.0 (Type 4: 10x)
# Indian Institute of Management Indore: Avg Type 4.0 (Type 4: 10x)
# Indian Statistical Institute, Delhi: Avg Type 4.0 (Type 4: 10x)
# Indira Gandhi Institute of Development Research (IGIDR): Avg Type 4.0 (Type 4: 10x)
# Insper (Institute of Education and Research): Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# Instituto Universitário de Lisboa, ISCTE-IUL: Avg Type 4.0 (Type 4: 10x)
# International Monetary Fund (IMF): Avg Type 4.0 (Type 4: 10x)
# Istanbul University: Avg Type 4.0 (Type 4: 10x)
# Jawaharlal Nehru University: Avg Type 4.0 (Type 4: 10x)
# Johannes Kepler University Linz: Avg Type 4.0 (Type 4: 10x)
# Kiel Institute for the World Economy: Avg Type 4.0 (Type 4: 10x)
# Kiel University: Avg Type 4.0 (Type 4: 10x)
# Korea University: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Koç University: Avg Type 3.7 (Type 3: 3x, Type 4: 7x)
# Kurukshetra University: Avg Type 4.0 (Type 4: 10x)
# Kyoto University: Avg Type 4.0 (Type 4: 10x)
# LUISS Guido Carli: Avg Type 4.0 (Type 4: 10x)
# Lehigh University: Avg Type 3.7 (Type 3: 3x, Type 4: 7x)
# Leibniz Universität Hannover: Avg Type 4.0 (Type 4: 10x)
# Libera Università di Bolzano: Avg Type 4.0 (Type 4: 10x)
# Loughborough University: Avg Type 4.0 (Type 4: 10x)
# Luleå University of Technology: Avg Type 4.0 (Type 4: 10x)
# MINES ParisTech: Avg Type 4.0 (Type 4: 10x)
# Manchester Metropolitan University: Avg Type 4.0 (Type 4: 10x)
# Martin Luther University of Halle-Wittenberg: Avg Type 4.0 (Type 4: 10x)
# Massey University: Avg Type 4.0 (Type 4: 10x)
# Maulana Azad National Institute of Technology Bhopal (MANIT): Avg Type 4.0 (Type 4: 10x)
# Meiji University: Avg Type 4.0 (Type 4: 10x)
# Middle East Technical University: Avg Type 4.0 (Type 4: 10x)
# Middle East Technical University - Northern Cyprus Campus: Avg Type 4.0 (Type 4: 10x)
# National Central University: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# National Research University Higher School of Economics, St. Petersburg: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Nelson Mandela University: Avg Type 4.0 (Type 4: 10x)
# Northern Illinois University: Avg Type 4.0 (Type 4: 10x)
# Otto-von-Guericke University Magdeburg: Avg Type 4.0 (Type 4: 10x)
# Politecnico di Torino: Avg Type 4.0 (Type 4: 10x)
# Quaid-i-Azam University: Avg Type 4.0 (Type 4: 10x)
# Queens' University Belfast: Avg Type 4.0 (Type 4: 10x)
# Radboud University: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Royal Holloway, University of London: Avg Type 4.0 (Type 4: 10x)
# Royal Melbourne Institute of Technology (RMIT): Avg Type 3.7 (Type 3: 3x, Type 4: 7x)
# SKEMA Business School: Avg Type 4.0 (Type 4: 10x)
# SOAS (School of Oriental and African Studies), University of London: Avg Type 4.0 (Type 4: 10x)
# SUNY Buffalo State: Avg Type 3.5 (Type 3: 5x, Type 4: 5x)
# Sam Houston State University: Avg Type 3.7 (Type 3: 3x, Type 4: 7x)
# Sapienza Università di Roma: Avg Type 4.0 (Type 4: 10x)
# Sciences Po Toulouse: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Seoul National University: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Shiv Nadar University: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# Sorbonne Université: Avg Type 4.0 (Type 4: 10x)
# Southern Illinois University: Avg Type 4.0 (Type 4: 10x)
# St. Thomas University: Avg Type 4.0 (Type 4: 10x)
# Stellenbosch University: Avg Type 4.0 (Type 4: 10x)
# Suffolk University: Avg Type 4.0 (Type 4: 10x)
# Technical University of Crete: Avg Type 4.0 (Type 4: 10x)
# Technische Universität Berlin: Avg Type 4.0 (Type 4: 10x)
# Technische Universität Braunschweig: Avg Type 4.0 (Type 4: 10x)
# Texas A&M International University: Avg Type 4.0 (Type 4: 10x)
# Towson University: Avg Type 4.0 (Type 4: 10x)
# Trinity College Dublin, University of Dublin: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# Universidad Complutense de Madrid: Avg Type 4.0 (Type 4: 10x)
# Universidad Pontificia Comillas: Avg Type 4.0 (Type 4: 10x)
# Universidad de Alicante: Avg Type 3.5 (Type 3: 5x, Type 4: 5x)
# Universidad de Cantabria: Avg Type 4.0 (Type 4: 10x)
# Universidad de Zaragoza: Avg Type 4.0 (Type 4: 10x)
# Universidade Nova de Lisboa: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Universidade da Coruña: Avg Type 4.0 (Type 4: 10x)
# Universitat Rovira i Virgili: Avg Type 4.0 (Type 4: 10x)
# Universitat de Barcelona: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Universitat de València: Avg Type 4.0 (Type 4: 10x)
# Universiti Kebangsaan Malaysia: Avg Type 4.0 (Type 4: 10x)
# Universiti Malaysia Perlis: Avg Type 4.0 (Type 4: 10x)
# Universiti Sains Malaysia: Avg Type 4.0 (Type 4: 10x)
# Universiti Utara Malaysia: Avg Type 4.0 (Type 4: 10x)
# University College Cork: Avg Type 4.0 (Type 4: 10x)
# University at Albany (SUNY): Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# University of Aberdeen: Avg Type 4.0 (Type 4: 10x)
# University of Adelaide: Avg Type 4.0 (Type 4: 10x)
# University of Algiers 3: Avg Type 4.0 (Type 4: 10x)
# University of Bath: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# University of Bern: Avg Type 4.0 (Type 4: 10x)
# University of Birmingham: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# University of Cape Town: Avg Type 4.0 (Type 4: 10x)
# University of Carthage: Avg Type 4.0 (Type 4: 10x)
# University of Cincinnati: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# University of Cologne: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# University of Colorado, Denver: Avg Type 3.7 (Type 3: 3x, Type 4: 7x)
# University of Dschang: Avg Type 4.0 (Type 4: 10x)
# University of Fribourg: Avg Type 4.0 (Type 4: 10x)
# University of Guelph: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# University of Helsinki: Avg Type 4.0 (Type 4: 10x)
# University of Hull: Avg Type 4.0 (Type 4: 10x)
# University of Innsbruck: Avg Type 4.0 (Type 4: 10x)
# University of Konstanz: Avg Type 4.0 (Type 4: 10x)
# University of Leeds: Avg Type 4.0 (Type 4: 10x)
# University of Limerick: Avg Type 4.0 (Type 4: 10x)
# University of Lisbon: Avg Type 4.0 (Type 4: 10x)
# University of Liverpool: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# University of Luxembourg: Avg Type 4.0 (Type 4: 10x)
# University of Maine, Orono: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# University of Manchester: Avg Type 3.7 (Type 3: 3x, Type 4: 7x)
# University of Minho: Avg Type 4.0 (Type 4: 10x)
# University of Mississippi: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# University of Nebraska, Lincoln: Avg Type 3.5 (Type 3: 5x, Type 4: 5x)
# University of Nevada, Las Vegas (UNLV): Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# University of Nevada, Reno: Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# University of New Mexico: Avg Type 3.7 (Type 3: 3x, Type 4: 7x)
# University of New Orleans: Avg Type 4.0 (Type 4: 10x)
# University of North Carolina, Greensboro: Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# University of Ottawa: Avg Type 3.5 (Type 3: 5x, Type 4: 5x)
# University of Porto: Avg Type 4.0 (Type 4: 10x)
# University of Reading: Avg Type 4.0 (Type 4: 10x)
# University of Saskatchewan: Avg Type 4.0 (Type 4: 10x)
# University of Sheffield: Avg Type 4.0 (Type 4: 10x)
# University of South Alabama: Avg Type 4.0 (Type 4: 10x)
# University of Strathclyde: Avg Type 4.0 (Type 4: 10x)
# University of Sussex: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# University of Tasmania: Avg Type 4.0 (Type 4: 10x)
# University of Tennessee, Knoxville: Avg Type 3.5 (Type 3: 5x, Type 4: 5x)
# University of Texas at Arlington: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# University of Tirana: Avg Type 4.0 (Type 4: 10x)
# University of Tsukuba: Avg Type 4.0 (Type 4: 10x)
# University of Vaasa: Avg Type 4.0 (Type 4: 10x)
# University of Victoria: Avg Type 4.0 (Type 4: 10x)
# University of Warsaw: Avg Type 4.0 (Type 4: 10x)
# University of Waterloo: Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# University of Wisconsin, Milwaukee: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# University of Wyoming: Avg Type 4.0 (Type 4: 10x)
# University of York: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# University of the West of Scotland: Avg Type 4.0 (Type 4: 10x)
# Università Cattolica del Sacro Cuore: Avg Type 4.0 (Type 4: 10x)
# Università Degli Studi di Milano: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Università degli Studi del Molise: Avg Type 4.0 (Type 4: 10x)
# Università degli Studi di Firenze: Avg Type 4.0 (Type 4: 10x)
# Università degli Studi di Palermo: Avg Type 4.0 (Type 4: 10x)
# Università degli Studi di Pavia: Avg Type 4.0 (Type 4: 10x)
# Università degli Studi di Siena: Avg Type 4.0 (Type 4: 10x)
# Università degli Studi di Trento: Avg Type 4.0 (Type 4: 10x)
# Università della Svizzera Italiana: Avg Type 4.0 (Type 4: 10x)
# Università di Roma Tor Vergata: Avg Type 3.7 (Type 3: 3x, Type 4: 7x)
# Université Cheikh Anta Diop de Dakar: Avg Type 4.0 (Type 4: 10x)
# Université Claude Bernard Lyon 1: Avg Type 4.0 (Type 4: 10x)
# Université Clermont Auvergne: Avg Type 4.0 (Type 4: 10x)
# Université Grenoble Alpes: Avg Type 4.0 (Type 4: 10x)
# Université Laval: Avg Type 4.0 (Type 4: 10x)
# Université Paris 1 Panthéon-Sorbonne: Avg Type 4.0 (Type 4: 10x)
# Université Paris 2 Panthéon-Assas: Avg Type 4.0 (Type 4: 10x)
# Université Paris-Dauphine: Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Université Paris-Est Créteil: Avg Type 4.0 (Type 4: 10x)
# Université Paris-Est Marne-la-Vallée: Avg Type 4.0 (Type 4: 10x)
# Université catholique de Louvain: Avg Type 4.0 (Type 4: 10x)
# Université d'Evry Val-d'Essonne: Avg Type 4.0 (Type 4: 10x)
# Université de Bordeaux: Avg Type 4.0 (Type 4: 10x)
# Université de Genève: Avg Type 3.8 (Type 3: 2x, Type 4: 8x)
# Université de Rennes 1: Avg Type 4.0 (Type 4: 10x)
# Université de Strasbourg: Avg Type 4.0 (Type 4: 10x)
# Université de Tunis: Avg Type 4.0 (Type 4: 10x)
# Vienna Graduate School of Finance (VGSF): Avg Type 3.9 (Type 3: 1x, Type 4: 9x)
# Vienna University of Economics and Business: Avg Type 3.6 (Type 3: 4x, Type 4: 6x)
# Wageningen University: Avg Type 4.0 (Type 4: 10x)
# Wayne State University: Avg Type 3.5 (Type 3: 5x, Type 4: 5x)
# Western Kentucky University: Avg Type 4.0 (Type 4: 10x)
# Yildiz Technical University: Avg Type 4.0 (Type 4: 10x)
# York University: Avg Type 4.0 (Type 4: 10x)
# Zhejiang Gongshang University: Avg Type 4.0 (Type 4: 10x)
# Total Institutions: 214
