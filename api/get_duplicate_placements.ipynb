# %%
#using Pkg
#Pkg.add("JSON")
#Pkg.add("DotEnv")
#Pkg.add("HTTP")
#Pkg.add("JSON")
#Pkg.add("URIs")
#Pkg.add("ConfigEnv")

using HTTP, URIs,JSON

# %% [markdown]
# This is a modified version of the get_data program in the api documentation.  Designed here to illustrate error correction methods

# %%
function get_data(url)
    resp = HTTP.get(url);
    es = String(resp.body)
    return placements = JSON.parse(es)
end
# Out:
# get_data (generic function with 1 method)

# %%
placements = get_data("https://support.econjobmarket.org/api/placement_data")
println(placements[1])
# Out:
# Dict{String, Any}("to_shortname" => "Econ, U Cattolica Sacro Cuore", "to_name" => "Università Cattolica del Sacro Cuore", "to_department" => "Facoltà di Economia", "name" => "Industrial Organization", "category_id" => 7, "from_shortname" => "Economics, UCLA", "to_oid" => 1783, "recruiter_type" => 1, "description" => "Academic organization (economics department)", "from_oid" => "36", "position_name" => "Lecturer", "year" => 2003, "aid" => 4256, "to_institution_id" => 1873, "postype" => 7, "from_institution_id" => "6", "from_institution_name" => "University of California Los Angeles (UCLA)")

# %% [markdown]
# To flag the entries I use an elementary method.  First I'll create an empty set to store the placements I have already checked called `records` and another set to hold the aids I want to flag called `flags`.
#
# Then I'll iterate through the placements one by one and check whether each placement is already in `records`.  If it is there already I'll try to add the aid to `flags`.  If it isn't there I'll add the record to `records`

# %%
records = Set()
flags = Set()
#x = [1,2,3]
#push!(s,[1,2,3])
#println(s)
# Out:
# Set{Any}()

# %%
for placement in placements
    t = [placement["aid"],placement["to_oid"],placement["from_oid"],placement["year"],placement["postype"]]
    #println( "checking ", t)
    if t in records
        push!(flags,placement["aid"])
    else
        push!(records,t)
    end 
end

# %%
println(length(records))
println(length(flags))
# Out:
# 16820
# 5

# %%
println(flags)
# Out:
# Set(Any[60375, 60130, 59967, 53029, 56188])
